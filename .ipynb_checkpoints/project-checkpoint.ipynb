# %% [markdown]
# # Stock Market

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
from datetime import datetime

company_name='GMRINFRA'

def open_data(name):
    return 'Updated_Stock_market_data\\'+name.upper()+'__EQ__NSE__NSE__MINUTE.csv'

dp=pd.read_csv(open_data(company_name))

# %%
dp
# Out:
#                         timestamp        date      time         quater   open  \
# 0       2017-01-02 09:15:00+05:30  2017-01-02  09:15:00  early morning  11.95
# 1       2017-01-02 09:16:00+05:30  2017-01-02  09:16:00  early morning  11.95
# 2       2017-01-02 09:17:00+05:30  2017-01-02  09:17:00  early morning  12.00
# 3       2017-01-02 09:18:00+05:30  2017-01-02  09:18:00  early morning  11.95
# 4       2017-01-02 09:19:00+05:30  2017-01-02  09:19:00  early morning  11.95
# ...                           ...         ...       ...            ...    ...
# 370540  2021-01-01 15:25:00+05:30  2021-01-01  15:25:00      afternoon  26.60
# 370541  2021-01-01 15:26:00+05:30  2021-01-01  15:26:00      afternoon  26.55
# 370542  2021-01-01 15:27:00+05:30  2021-01-01  15:27:00      afternoon  26.60
# 370543  2021-01-01 15:28:00+05:30  2021-01-01  15:28:00      afternoon  26.65
# 370544  2021-01-01 15:29:00+05:30  2021-01-01  15:29:00      afternoon  26.65
#
#          high    low  close    volume   %change         MA
# 0       11.95  11.90  11.95   45047.0  0.000000  11.950000
# 1       12.00  11.95  12.00   60600.0  0.418410  11.975000
# 2       12.00  11.95  11.95    8365.0 -0.416667  11.966667
# 3       12.00  11.95  11.95   86438.0  0.000000  11.962500
# 4       12.00  11.95  11.95   42662.0  0.000000  11.960000
# ...       ...    ...    ...       ...       ...        ...
# 370540  26.60  26.55  26.55    7932.0  0.000000  18.449000
# 370541  26.65  26.55  26.60  127784.0  0.188324  18.449022
# 370542  26.65  26.60  26.65   50378.0  0.187970  18.449044
# 370543  26.65  26.60  26.60   41461.0 -0.187617  18.449066
# 370544  26.70  26.60  26.65  130848.0  0.187970  18.449088
#
# [370545 rows x 11 columns]

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370545 entries, 0 to 370544
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  370545 non-null  object
#  1   date       370545 non-null  object
#  2   time       370545 non-null  object
#  3   quater     370545 non-null  object
#  4   open       370364 non-null  float64
#  5   high       370364 non-null  float64
#  6   low        370364 non-null  float64
#  7   close      370364 non-null  float64
#  8   volume     370364 non-null  float64
#  9   %change    370315 non-null  float64
#  10  MA         370545 non-null  float64
# dtypes: float64(7), object(4)
# memory usage: 31.1+ MB

# %%
dp['timestamp'] = pd.to_datetime(dp['timestamp'],format='%Y-%m-%d %H:%M:%S%z')
dp['date']=pd.to_datetime(dp['date'])
dp['time'] = pd.to_datetime(dp['time'],format='%H:%M:%S').dt.time

# %%
dp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370545 entries, 0 to 370544
# Data columns (total 11 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   timestamp  370545 non-null  datetime64[ns, pytz.FixedOffset(330)]
#  1   date       370545 non-null  datetime64[ns]
#  2   time       370545 non-null  object
#  3   quater     370545 non-null  object
#  4   open       370364 non-null  float64
#  5   high       370364 non-null  float64
#  6   low        370364 non-null  float64
#  7   close      370364 non-null  float64
#  8   volume     370364 non-null  float64
#  9   %change    370315 non-null  float64
#  10  MA         370545 non-null  float64
# dtypes: datetime64[ns, pytz.FixedOffset(330)](1), datetime64[ns](1), float64(7), object(2)
# memory usage: 31.1+ MB

# %%
dp.describe()
# Out:
#                 open           high            low          close  \
# count  370364.000000  370364.000000  370364.000000  370364.000000
# mean       18.449363      18.478003      18.421717      18.449561
# std         3.128215       3.132708       3.126355       3.128086
# min        11.850000      11.850000      11.850000      11.850000
# 25%        16.200000      16.250000      16.200000      16.200000
# 50%        17.550000      17.600000      17.550000      17.550000
# 75%        20.500000      20.550000      20.450000      20.500000
# max        29.250000      29.350000      29.150000      29.250000
#
#              volume        %change             MA
# count  3.703640e+05  370315.000000  370545.000000
# mean   7.046237e+04       0.000515      16.934373
# std    2.377176e+05       0.247227       1.217381
# min    0.000000e+00      -9.876543      11.932212
# 25%    2.261000e+03       0.000000      16.782200
# 50%    1.195550e+04       0.000000      17.319312
# 75%    6.155225e+04       0.000000      17.582178
# max    2.812544e+07       6.292135      18.449088

# %%
dp.isnull().sum()
# Out:
# timestamp      0
# date           0
# time           0
# quater         0
# open         181
# high         181
# low          181
# close        181
# volume       181
# %change      230
# MA             0
# dtype: int64

# %%
dp[dp.isna().any(axis=1)]
# Out:
#                        timestamp       date      time     quater   open  high  \
# 188032 2019-01-14 13:07:00+05:30 2019-01-14  13:07:00  afternoon    NaN   NaN
# 188033 2019-01-14 13:08:00+05:30 2019-01-14  13:08:00  afternoon  16.45  16.5
# 190983 2019-01-24 12:18:00+05:30 2019-01-24  12:18:00  afternoon    NaN   NaN
# 190984 2019-01-24 12:19:00+05:30 2019-01-24  12:19:00  afternoon  16.00  16.0
# 212009 2019-04-16 12:44:00+05:30 2019-04-16  12:44:00  afternoon    NaN   NaN
# ...                          ...        ...       ...        ...    ...   ...
# 337678 2020-08-27 12:28:00+05:30 2020-08-27  12:28:00  afternoon    NaN   NaN
# 337679 2020-08-27 12:29:00+05:30 2020-08-27  12:29:00  afternoon    NaN   NaN
# 337680 2020-08-27 12:30:00+05:30 2020-08-27  12:30:00  afternoon  26.25  26.3
# 355092 2020-11-02 15:12:00+05:30 2020-11-02  15:12:00  afternoon    NaN   NaN
# 355093 2020-11-02 15:13:00+05:30 2020-11-02  15:13:00  afternoon  23.45  23.5
#
#           low  close    volume  %change         MA
# 188032    NaN    NaN       NaN      NaN  17.385987
# 188033  16.45  16.50      51.0      NaN  17.385983
# 190983    NaN    NaN       NaN      NaN  17.369128
# 190984  15.95  15.95     400.0      NaN  17.369121
# 212009    NaN    NaN       NaN      NaN  17.314465
# ...       ...    ...       ...      ...        ...
# 337678    NaN    NaN       NaN      NaN  17.850768
# 337679    NaN    NaN       NaN      NaN  17.850768
# 337680  26.25  26.25  438057.0      NaN  17.850793
# 355092    NaN    NaN       NaN      NaN  18.131449
# 355093  23.45  23.45   43293.0      NaN  18.131464
#
# [230 rows x 11 columns]

# %%
#Cleaning NULL of open,close,high,low
for i in dp.index:
    if math.isnan(dp.loc[i,'open']):
        j=i-1
        while(j>0 and math.isnan(dp.loc[j,'open'])==True):
            j-=1
        dp.loc[i,'open']=dp.loc[j,'open']
    if math.isnan(dp.loc[i,'close']):
        j=i-1
        while(j>0 and math.isnan(dp.loc[j,'close'])==True):
            j-=1
        dp.loc[i,'close']=dp.loc[j,'close']
    if math.isnan(dp.loc[i,'high']):
        j=i-1
        while(j>0 and math.isnan(dp.loc[j,'high'])==True):
            j-=1
        dp.loc[i,'high']=dp.loc[j,'high']
    if math.isnan(dp.loc[i,'low']):
        j=i-1
        while(j>0 and math.isnan(dp.loc[j,'low'])==True):
            j-=1
        dp.loc[i,'low']=dp.loc[j,'low']

# %%
#Cleaning NULL of volume
dp['volume'].fillna(0,inplace=True)

# %%
#Cleaning NULL of %Chnage
#%Change=(curr_close-prev_close)/prev_close*100
#Recalculate change for NULL values
for i in dp.index:
    if math.isnan(dp.loc[i,'%change']):
        dp.loc[i,'%change']=(dp.loc[i,'close']-dp.loc[i-1,'close'])/dp.loc[i-1,'close']*100

# %%
dp.isnull().sum()
# Out:
# timestamp    0
# date         0
# time         0
# quater       0
# open         0
# high         0
# low          0
# close        0
# volume       0
# %change      0
# MA           0
# dtype: int64

# %%
print("Maximum stock price of",company_name,"is",dp['high'].max())
print("Minimum stock price of",company_name,"is",dp['low'].min())
print("Maximum stocks purchased at a time of",company_name,"is",dp['volume'].max())
print("Minimum stocks purchased at a time of",company_name,"is",dp['volume'].min())
# Out:
# Maximum stock price of GMRINFRA is 29.35
# Minimum stock price of GMRINFRA is 11.85
# Maximum stocks purchased at a time of GMRINFRA is 28125437.0
# Minimum stocks purchased at a time of GMRINFRA is 0.0

# %%
fig, ax = plt.subplots()

dp.plot(x='timestamp',y='open',color='red',ax=ax)
dp.plot(x='timestamp',y='close',color='green',ax=ax)

plt.title('Stock Prices of '+company_name)
plt.show()

# %%
def get_date(date):
    return np.datetime64(datetime.strptime(date, "%Y-%m-%d").date())

# %%
day=get_date('2020-01-02')

dp_day = dp[dp['date'] == day]

fig, ax = plt.subplots()
dp_day.plot(x='timestamp',y='open',color='red',ax=ax)
dp_day.plot(x='timestamp',y='close',color='green',ax=ax)

plt.title('Stock Prices of '+company_name+' of date '+str(day))
plt.show()

# %%
fig, ax = plt.subplots()

dp.plot(x='timestamp',y='MA',color='red',ax=ax)

plt.title('Moving Average of '+company_name)
plt.show()

# %%
# Convert the datetime object to an integer timestamp
dp['int_timestamp'] = dp['timestamp'].apply(lambda x: int(x.timestamp()))

# %%
mapping={'early morning':1, 'late morning':2, 'afternoon':3}
dp['quater']=dp['quater'].replace(mapping)

# %%
for i in dp.index:
    if dp.loc[i,'%change'] > 0:
        dp.loc[i,'target']=1
    else:
        dp.loc[i,'target']=0

# %%
dp['profit']=dp['close']-dp['open']

# %%
dp['diff']=dp['high']-dp['low']

# %%
corr = dp.corr(method = 'pearson')
corr
# Out:
# C:\Users\Shivan\AppData\Local\Temp\ipykernel_6344\3384302169.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = dp.corr(method = 'pearson')
#                  quater      open      high       low     close    volume  \
# quater         1.000000 -0.001177 -0.001860 -0.000447 -0.001166 -0.012761
# open          -0.001177  1.000000  0.999940  0.999942  0.999903  0.040536
# high          -0.001860  0.999940  1.000000  0.999931  0.999945  0.043151
# low           -0.000447  0.999942  0.999931  1.000000  0.999941  0.038292
# close         -0.001166  0.999903  0.999945  0.999941  1.000000  0.041011
# volume        -0.012761  0.040536  0.043151  0.038292  0.041011  1.000000
# %change       -0.003099 -0.004974  0.000764  0.000258  0.006837  0.041759
# MA             0.001209  0.495602  0.495603  0.495665  0.495685 -0.014505
# int_timestamp -0.000195  0.551600  0.551340  0.552026  0.551603 -0.076618
# target        -0.024295 -0.000401  0.004923  0.002350  0.008601  0.084176
# profit         0.000836 -0.009683 -0.002398 -0.002776  0.004239  0.034065
# diff          -0.118621  0.169864  0.175774  0.164190  0.170305  0.414246
#
#                 %change        MA  int_timestamp    target    profit      diff
# quater        -0.003099  0.001209      -0.000195 -0.024295  0.000836 -0.118621
# open          -0.004974  0.495602       0.551600 -0.000401 -0.009683  0.169864
# high           0.000764  0.495603       0.551340  0.004923 -0.002398  0.175774
# low            0.000258  0.495665       0.552026  0.002350 -0.002776  0.164190
# close          0.006837  0.495685       0.551603  0.008601  0.004239  0.170305
# volume         0.041759 -0.014505      -0.076618  0.084176  0.034065  0.414246
# %change        1.000000 -0.001517      -0.000205  0.727980  0.848327  0.042489
# MA            -0.001517  1.000000       0.733986  0.002046  0.004644  0.079050
# int_timestamp -0.000205  0.733986       1.000000 -0.021022 -0.001277  0.036257
# target         0.727980  0.002046      -0.021022  1.000000  0.646641  0.216311
# profit         0.848327  0.004644      -0.001277  0.646641  1.000000  0.031171
# diff           0.042489  0.079050       0.036257  0.216311  0.031171  1.000000

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots()
sns.heatmap(corr, annot=True,fmt='.2f', cmap='coolwarm',ax=ax)

plt.title('Correlation Heatmap')
plt.show()

# %%
fig, ax = plt.subplots()

dp.plot(x='timestamp',y='MA',color='red',ax=ax)

plt.title('Moving average vs Timestamp '+company_name)
plt.show()

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
X_1=dp[['int_timestamp']]
Y_1=dp['MA']
X_1_train, X_1_test, Y_1_train, Y_1_test = train_test_split(X_1,Y_1,test_size=0.2, random_state=42)

# %%
linear_1=LinearRegression()
linear_1.fit(X_1_train,Y_1_train)
# Out:
# LinearRegression()

# %%
X_2=dp[['int_timestamp','MA']]
Y_2=dp['open']
X_2_train, X_2_test, Y_2_train, Y_2_test = train_test_split(X_2,Y_2,test_size=0.2, random_state=42)

# %%
linear_2=LinearRegression()
linear_2.fit(X_2_train,Y_2_train)
# Out:
# LinearRegression()

# %%
X_3=dp[['int_timestamp','MA','open']]
Y_3=dp['close']
X_3_train, X_3_test, Y_3_train, Y_3_test = train_test_split(X_3,Y_3,test_size=0.2, random_state=42)

# %%
linear_3=LinearRegression()
linear_3.fit(X_3_train,Y_3_train)
# Out:
# LinearRegression()

# %%
X_4=dp[['int_timestamp','MA','open','close']]
Y_4=dp['high']
X_4_train, X_4_test, Y_4_train, Y_4_test = train_test_split(X_4,Y_4,test_size=0.2, random_state=42)

# %%
linear_4=LinearRegression()
linear_4.fit(X_4_train,Y_4_train)
# Out:
# LinearRegression()

# %%
X_5=dp[['int_timestamp','MA','open','close','high']]
Y_5=dp['low']
X_5_train, X_5_test, Y_5_train, Y_5_test = train_test_split(X_5,Y_5,test_size=0.2, random_state=42)

# %%
linear_5=LinearRegression()
linear_5.fit(X_5_train,Y_5_train)
# Out:
# LinearRegression()

# %%
Y_1_pred = linear_1.predict(X_1_test)
Y_2_pred = linear_2.predict(X_2_test)
Y_3_pred = linear_3.predict(X_3_test)
Y_4_pred = linear_4.predict(X_4_test)
Y_5_pred = linear_5.predict(X_5_test)

# %%
Y1_mse=mean_squared_error(Y_1_test,Y_1_pred)
Y2_mse=mean_squared_error(Y_2_test,Y_2_pred)
Y3_mse=mean_squared_error(Y_3_test,Y_3_pred)
Y4_mse=mean_squared_error(Y_4_test,Y_4_pred)
Y5_mse=mean_squared_error(Y_5_test,Y_5_pred)
print("Mean Square Error for MA:",Y1_mse)
print("Mean Square Error for open:",Y2_mse)
print("Mean Square Error for close:",Y3_mse)
print("Mean Square Error for high:",Y4_mse)
print("Mean Square Error for low:",Y5_mse)
# Out:
# Mean Square Error for MA: 0.681561275914831
# Mean Square Error for open: 6.670817967219985
# Mean Square Error for close: 0.0019042509203748925
# Mean Square Error for high: 0.0006570024659466621
# Mean Square Error for low: 0.0006728098888524553

# %%
specific_date = '2021-07-14'
specific_time = '15:30:00'

# %%
#timestamp='2019-05-06 14:01:00+05:30'
timestamp_str=specific_date+' '+specific_time+'+05:30'
timestamp=pd.to_datetime(timestamp_str)
int_timestamp = int(timestamp.timestamp())

# %%
test_value = pd.DataFrame({'int_timestamp': [int_timestamp]})
test_value
# Out:
#    int_timestamp
# 0     1626256800

# %%
predicted_ma = linear_1.predict(test_value)
test_value['MA']=predicted_ma
predicted_open = linear_2.predict(test_value)
test_value['open']=predicted_open
predicted_close = linear_3.predict(test_value)
test_value['close']=predicted_close
predicted_high = linear_4.predict(test_value)
test_value['high']=predicted_high
predicted_low = linear_5.predict(test_value)
test_value['low']=predicted_low

# Print the predicted values
print("Predicted Open:", predicted_open)
print("Predicted High:", predicted_high)
print("Predicted Low:", predicted_low)
print("Predicted Close:", predicted_close)
# Out:
# Predicted Open: [22.22102903]
# Predicted High: [22.25326726]
# Predicted Low: [22.19410753]
# Predicted Close: [22.22102357]

# %%
df=dp[['int_timestamp']]
predicted_ma = linear_1.predict(dp[['int_timestamp']])
df['MA']=predicted_ma
predicted_open = linear_2.predict(df)
df['open']=predicted_open
predicted_close = linear_3.predict(df)
df['close']=predicted_close
predicted_high = linear_4.predict(df)
df['high']=predicted_high
predicted_low = linear_5.predict(df)
df['low']=predicted_low
df['timestamp']=dp['timestamp']
# Out:
# C:\Users\Shivan\AppData\Local\Temp\ipykernel_6344\2426489568.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MA']=predicted_ma
# C:\Users\Shivan\AppData\Local\Temp\ipykernel_6344\2426489568.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['open']=predicted_open
# C:\Users\Shivan\AppData\Local\Temp\ipykernel_6344\2426489568.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['close']=predicted_close
# C:\Users\Shivan\AppData\Local\Temp\ipykernel_6344\2426489568.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['high']=predicted_high
# C:\Users\Shivan\AppData\Local\Temp\ipykernel_6344\2426489568.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['low']=predicted_low
# C:\Users\Shivan\AppData\Local\Temp\ipykernel_6344\2426489568.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['timestamp']=dp['timestamp']

# %%
df
# Out:
#         int_timestamp         MA       open      close       high        low  \
# 0          1483328700  15.392880  15.468601  15.468849  15.494371  15.440362
# 1          1483328760  15.392881  15.468604  15.468852  15.494374  15.440365
# 2          1483328820  15.392883  15.468607  15.468855  15.494377  15.440368
# 3          1483328880  15.392884  15.468610  15.468858  15.494380  15.440371
# 4          1483328940  15.392886  15.468613  15.468861  15.494382  15.440374
# ...               ...        ...        ...        ...        ...        ...
# 370540     1609494900  18.472847  21.429138  21.429162  21.460617  21.402062
# 370541     1609494960  18.472849  21.429141  21.429165  21.460620  21.402065
# 370542     1609495020  18.472850  21.429143  21.429168  21.460623  21.402067
# 370543     1609495080  18.472852  21.429146  21.429171  21.460626  21.402070
# 370544     1609495140  18.472853  21.429149  21.429173  21.460629  21.402073
#
#                        timestamp
# 0      2017-01-02 09:15:00+05:30
# 1      2017-01-02 09:16:00+05:30
# 2      2017-01-02 09:17:00+05:30
# 3      2017-01-02 09:18:00+05:30
# 4      2017-01-02 09:19:00+05:30
# ...                          ...
# 370540 2021-01-01 15:25:00+05:30
# 370541 2021-01-01 15:26:00+05:30
# 370542 2021-01-01 15:27:00+05:30
# 370543 2021-01-01 15:28:00+05:30
# 370544 2021-01-01 15:29:00+05:30
#
# [370545 rows x 7 columns]

# %%
fig, ax = plt.subplots()

dp.plot(x='timestamp',y='open',color='red',ax=ax)
df.plot(x='timestamp',y='open',color='green',ax=ax)

plt.title('Stock Prices of '+company_name)
plt.show()

# %%
fig, ax = plt.subplots()

dp.plot(x='timestamp',y='close',color='red',ax=ax)
df.plot(x='timestamp',y='close',color='green',ax=ax)

plt.title('Stock Prices of '+company_name)
plt.show()

# %%
fig, ax = plt.subplots()

dp.plot(x='timestamp',y='high',color='red',ax=ax)
df.plot(x='timestamp',y='high',color='green',ax=ax)

plt.title('Stock Prices of '+company_name)
plt.show()

# %%
fig, ax = plt.subplots()

dp.plot(x='timestamp',y='low',color='red',ax=ax)
df.plot(x='timestamp',y='low',color='green',ax=ax)

plt.title('Stock Prices of '+company_name)
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
# Should buy or not using logistic regression
X_target=dp[['int_timestamp','MA','open','close','high','low','%change','profit']]
Y_target=dp['target']
X_train,X_test,y_train,y_test=train_test_split(X_target,Y_target,test_size=0.2,random_state=42)

# %%
K = []
training = []
test = []
scores = {}
  
k=5000

clf = KNeighborsClassifier(n_neighbors = k)
clf.fit(X_train, y_train)

training_score = clf.score(X_train, y_train)
test_score = clf.score(X_test, y_test)
K.append(k)

training.append(training_score)
test.append(test_score)
scores[k] = [training_score, test_score]
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6344\3691844430.py in <cell line: 11>()
#       9 clf.fit(X_train, y_train)
#      10
# ---> 11 training_score = clf.score(X_train, y_train)
#      12 test_score = clf.score(X_test, y_test)
#      13 K.append(k)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     666         from .metrics import accuracy_score
#     667
# --> 668         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#     669
#     670     def _more_tags(self):
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py in predict(self, X)
#     232             # In that case, we do not need the distances to perform
#     233             # the weighting so we do not compute them.
# --> 234             neigh_ind = self.kneighbors(X, return_distance=False)
#     235             neigh_dist = None
#     236         else:
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in kneighbors(self, X, n_neighbors, return_distance)
#     877                     % self._fit_method
#     878                 )
# --> 879             chunked_results = Parallel(n_jobs, prefer="threads")(
#     880                 delayed(_tree_query_parallel_helper)(
#     881                     self._tree, X[s], n_neighbors, return_distance
#
# ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1083             # remaining jobs.
#    1084             self._iterating = False
# -> 1085             if self.dispatch_one_batch(iterator):
#    1086                 self._iterating = self._original_iterator is not None
#    1087
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~\anaconda3\lib\site-packages\sklearn\utils\parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\sklearn\neighbors\_base.py in _tree_query_parallel_helper(tree, *args, **kwargs)
#     683     under PyPy.
#     684     """
# --> 685     return tree.query(*args, **kwargs)
#     686
#     687
#
# sklearn\neighbors\_binary_tree.pxi in sklearn.neighbors._kd_tree.BinaryTree.query()
#
# sklearn\neighbors\_binary_tree.pxi in sklearn.neighbors._kd_tree.NeighborsHeap.__init__()
#
# MemoryError: Unable to allocate 11.0 GiB for an array with shape (296436, 5000) and data type int64

# %%
for keys, values in scores.items():
    print(keys, ':', values)

# %%
y_pred = logreg.predict(X_test)
# import the metrics class
from sklearn import metrics

cnf_matrix = metrics.confusion_matrix(Y_test, y_pred)
cnf_matrix
# Out:
# array([[56637,     0],
#        [17472,     0]], dtype=int64)

# %%
y_pred_proba = logreg.predict_proba(X_test)[::,1]
auc = metrics.roc_auc_score(Y_test, y_pred_proba)
auc
# Out:
# 0.5120656301010464

# %%
specific_date = '2021-07-14'
specific_time = '15:30:00'
#timestamp='2019-05-06 14:01:00+05:30'
timestamp_str=specific_date+' '+specific_time+'+05:30'
timestamp=pd.to_datetime(timestamp_str)
int_timestamp = int(timestamp.timestamp())
test_value = pd.DataFrame({'int_timestamp': [int_timestamp]})
test_value
# Out:
#    int_timestamp
# 0     1626256800

# %%
predicted_ma = linear_1.predict(test_value)
test_value['MA']=predicted_ma
predicted_open = linear_2.predict(test_value)
test_value['open']=predicted_open
predicted_close = linear_3.predict(test_value)
test_value['close']=predicted_close
predicted_high = linear_4.predict(test_value)
test_value['high']=predicted_high
predicted_low = linear_5.predict(test_value)
test_value['low']=predicted_low
predicted_target=logreg.predict(test_value)


# Print the predicted values
print("Predicted Open:", predicted_open)
print("Predicted High:", predicted_high)
print("Predicted Low:", predicted_low)
print("Predicted Close:", predicted_close)
print("Predicted Target:", predicted_target)
# Out:
# Predicted Open: [22.22102903]
# Predicted High: [22.25326726]
# Predicted Low: [22.19410753]
# Predicted Close: [22.22102357]
# Predicted Target: [0.]
